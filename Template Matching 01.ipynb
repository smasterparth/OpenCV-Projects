# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('sammy.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img_temp = cv2.imread('sammy_face.jpg')
img_temp = cv2.cvtColor(img_temp, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_temp)

# %%
img.shape, img_temp.shape
# Out:
# ((1367, 1025, 3), (375, 486, 3))

# %%
sum([1,2,3])
# Out:
# 6

# %%
my_s = eval('sum')

# %%
my_s([1,2])
# Out:
# 3

# %%
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR','cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF','cv2.TM_SQDIFF_NORMED']

# %%
for m in methods:
    
    full_copy = img.copy()
    method = eval(m)
    res = cv2.matchTemplate(full_copy, img_temp, method)
    
    min_val,max_val,min_loc,max_loc = cv2.minMaxLoc(res)
    
    if method in [cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
        
    height, width, channels = img.shape
    
    bottom_right = (top_left[0]+width,top_left[1]+height)
    
    cv2.rectangle(full_copy,top_left, bottom_right, (255,0,255),8)
    
    plt.subplot(121)
    plt.imshow(res)
    plt.title('HeatMap of template Matching')
    
    plt.subplot(122)
    plt.imshow(full_copy)
    plt.title('Detection of face')
    plt.suptitle(m)
    
    plt.show()

# %%
my_method = eval('cv2.TM_CCOEFF')
res_1 = cv2.matchTemplate(img, img_temp,my_method)

# %%
plt.imshow(res_1)
